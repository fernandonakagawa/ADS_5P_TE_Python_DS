# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandonakagawa/ADS_5P_TE_Python_DS/blob/main/Aula_16_Algoritmos_supervisionados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade da Aula 15 - Limpeza de dados

# %%
import pandas as pd
import numpy as np
#ler arquivo do excel e transformar em um dataframe
df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Python para Data Science/clientes_d.xlsx", index_col = None, header = None)
df
# Out:
#                                                    0
# 0  Name Hussein Hakeem Address Number 22 Fioye Cr...
# 1  Name Arojoye Samuel Address 11 Omolade Close O...
# 2  Name Alex Ezurum Address 1 Adamu Lane, Abuja A...
# 3  Name Susan Nwaimo Address Number 58 Yaba Stree...
# 4  Name Ajao Opeyemi Address No12 Olubunmi Street...
# 5  Name Banjoko Adebusola Address 34 Ngige Street...
# 6  Name Muhammed Olabisi Address 13, ICAN road, E...
# 7  Name Oluwagbemi Mojisola Address ACCA Lane, On...
# 8  Name Susan Nwaimo Address Number 58 Yaba Stree...
# 9  Name Ajao Opeyemi Address No12 Olubunmi Street...

# %%
columns = ['Name', 'Address', 'Age', 'Gender']
for index, linha in df.iterrows():
  print(linha)
# Out:
# 0    Name Hussein Hakeem Address Number 22 Fioye Cr...
# Name: 0, dtype: object
# 0    Name Arojoye Samuel Address 11 Omolade Close O...
# Name: 1, dtype: object
# 0    Name Alex Ezurum Address 1 Adamu Lane, Abuja A...
# Name: 2, dtype: object
# 0    Name Susan Nwaimo Address Number 58 Yaba Stree...
# Name: 3, dtype: object
# 0    Name Ajao Opeyemi Address No12 Olubunmi Street...
# Name: 4, dtype: object
# 0    Name Banjoko Adebusola Address 34 Ngige Street...
# Name: 5, dtype: object
# 0    Name Muhammed Olabisi Address 13, ICAN road, E...
# Name: 6, dtype: object
# 0    Name Oluwagbemi Mojisola Address ACCA Lane, On...
# Name: 7, dtype: object
# 0    Name Susan Nwaimo Address Number 58 Yaba Stree...
# Name: 8, dtype: object
# 0    Name Ajao Opeyemi Address No12 Olubunmi Street...
# Name: 9, dtype: object

# %%
df2 = pd.DataFrame(columns = columns)
df2
# Out:
# Empty DataFrame
# Columns: [Name, Address, Age, Gender]
# Index: []

# %%
df[0]
# Out:
# 0    Name Hussein Hakeem Address Number 22 Fioye Cr...
# 1    Name Arojoye Samuel Address 11 Omolade Close O...
# 2    Name Alex Ezurum Address 1 Adamu Lane, Abuja A...
# 3    Name Susan Nwaimo Address Number 58 Yaba Stree...
# 4    Name Ajao Opeyemi Address No12 Olubunmi Street...
# 5    Name Banjoko Adebusola Address 34 Ngige Street...
# 6    Name Muhammed Olabisi Address 13, ICAN road, E...
# 7    Name Oluwagbemi Mojisola Address ACCA Lane, On...
# 8    Name Susan Nwaimo Address Number 58 Yaba Stree...
# 9    Name Ajao Opeyemi Address No12 Olubunmi Street...
# Name: 0, dtype: object

# %%
#Tornar os nomes das colunas em separadores
df = df[0].str.split(pat = 'Name|Address|Age|Gender', expand = True)
df
# Out:
#   0                      1                                          2      3  \
# 0          Hussein Hakeem    Number 22 Fioye Crescent Surulere Lagos     17
# 1          Arojoye Samuel        11 Omolade Close Omole Estate Lagos     16
# 2             Alex Ezurum                        1 Adamu Lane, Abuja    140
# 3            Susan Nwaimo       Number 58 Yaba Street, Kaduna State     160
# 4            Ajao Opeyemi             No12 Olubunmi Street, Abeokuta     18
# 5       Banjoko Adebusola             34 Ngige Street, Ugheli, Delta     14
# 6        Muhammed Olabisi                       13, ICAN road, Enugu      ?
# 7     Oluwagbemi Mojisola                         ACCA Lane, Onitsha     1O
# 8            Susan Nwaimo       Number 58 Yaba Street, Kaduna State      16
# 9            Ajao Opeyemi             No12 Olubunmi Street, Abeokuta     18
#
#          4
# 0     Male
# 1     Male
# 2     Male
# 3   Female
# 4   Female
# 5   Female
# 6   Female
# 7   Female
# 8   Female
# ...

# %%
#drop na coluna 0
df.drop(columns=[0], inplace = True)
df
# Out:
#                        1                                          2      3  \
# 0        Hussein Hakeem    Number 22 Fioye Crescent Surulere Lagos     17
# 1        Arojoye Samuel        11 Omolade Close Omole Estate Lagos     16
# 2           Alex Ezurum                        1 Adamu Lane, Abuja    140
# 3          Susan Nwaimo       Number 58 Yaba Street, Kaduna State     160
# 4          Ajao Opeyemi             No12 Olubunmi Street, Abeokuta     18
# 5     Banjoko Adebusola             34 Ngige Street, Ugheli, Delta     14
# 6      Muhammed Olabisi                       13, ICAN road, Enugu      ?
# 7   Oluwagbemi Mojisola                         ACCA Lane, Onitsha     1O
# 8          Susan Nwaimo       Number 58 Yaba Street, Kaduna State      16
# 9          Ajao Opeyemi             No12 Olubunmi Street, Abeokuta     18
#
#          4
# 0     Male
# 1     Male
# 2     Male
# 3   Female
# 4   Female
# 5   Female
# 6   Female
# 7   Female
# 8   Female
# 9   Female

# %%
#renomear as colunas
df.rename(columns = {1:'Name', 2:'Address', 3:'Age', 4:'Gender'}, inplace = True)
df
# Out:
#                     Name                                    Address    Age  \
# 0        Hussein Hakeem    Number 22 Fioye Crescent Surulere Lagos     17
# 1        Arojoye Samuel        11 Omolade Close Omole Estate Lagos     16
# 2           Alex Ezurum                        1 Adamu Lane, Abuja    140
# 3          Susan Nwaimo       Number 58 Yaba Street, Kaduna State     160
# 4          Ajao Opeyemi             No12 Olubunmi Street, Abeokuta     18
# 5     Banjoko Adebusola             34 Ngige Street, Ugheli, Delta     14
# 6      Muhammed Olabisi                       13, ICAN road, Enugu      ?
# 7   Oluwagbemi Mojisola                         ACCA Lane, Onitsha     1O
# 8          Susan Nwaimo       Number 58 Yaba Street, Kaduna State      16
# 9          Ajao Opeyemi             No12 Olubunmi Street, Abeokuta     18
#
#     Gender
# 0     Male
# 1     Male
# 2     Male
# 3   Female
# 4   Female
# 5   Female
# 6   Female
# 7   Female
# 8   Female
# 9   Female

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     10 non-null     object
#  1   Address  10 non-null     object
#  2   Age      10 non-null     object
#  3   Gender   10 non-null     object
# dtypes: object(4)
# memory usage: 448.0+ bytes

# %%
#ainda não é possível 
df['Age'].loc[df['Age'] > 100]
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-2b48250f544f> in <module>()
# ----> 1 df['Age'].loc[df['Age'] > 100]
#       2 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      46     @unpack_zerodim_and_defer("__gt__")
#      47     def __gt__(self, other):
# ---> 48         return self._cmp_method(other, operator.gt)
#      49
#      50     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# ...

# %%
#mostra informações do dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     10 non-null     object
#  1   Address  10 non-null     object
#  2   Age      10 non-null     object
#  3   Gender   10 non-null     object
# dtypes: object(4)
# memory usage: 448.0+ bytes

# %%
df['Age'] = pd.to_numeric(df.Age, downcast = "integer")
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " ? "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-bf2ee2884d55> in <module>()
#       1
# ----> 2 df['Age'] = pd.to_numeric(df.Age, downcast = "integer")
#       3 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     182         try:
#     183             values, _ = lib.maybe_convert_numeric(
# --> 184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#     186         except (ValueError, TypeError):
#
# ...

# %%
df['Age'].str.contains(pat = '\\d')
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# 7     True
# 8     True
# 9     True
# Name: Age, dtype: bool

# %%
#todos os registros da coluna "Age" contendo '?' terão valor substituído por -1
df['Age'].loc[df['Age'].str.contains(pat = '?', regex = False)] = '-1'

# %%
df
# Out:
#                     Name                                    Address    Age  \
# 0        Hussein Hakeem    Number 22 Fioye Crescent Surulere Lagos     17
# 1        Arojoye Samuel        11 Omolade Close Omole Estate Lagos     16
# 2           Alex Ezurum                        1 Adamu Lane, Abuja    140
# 3          Susan Nwaimo       Number 58 Yaba Street, Kaduna State     160
# 4          Ajao Opeyemi             No12 Olubunmi Street, Abeokuta     18
# 5     Banjoko Adebusola             34 Ngige Street, Ugheli, Delta     14
# 6      Muhammed Olabisi                       13, ICAN road, Enugu      -1
# 7   Oluwagbemi Mojisola                         ACCA Lane, Onitsha     1O
# 8          Susan Nwaimo       Number 58 Yaba Street, Kaduna State      16
# 9          Ajao Opeyemi             No12 Olubunmi Street, Abeokuta     18
#
#     Gender
# 0     Male
# 1     Male
# 2     Male
# 3   Female
# 4   Female
# 5   Female
# 6   Female
# 7   Female
# 8   Female
# 9   Female

# %%
df['Age'].loc[df['Age'].str.contains(pat = 'O', regex = False)] = '-1'

# %%
df
# Out:
#                     Name                                    Address    Age  \
# 0        Hussein Hakeem    Number 22 Fioye Crescent Surulere Lagos     17
# 1        Arojoye Samuel        11 Omolade Close Omole Estate Lagos     16
# 2           Alex Ezurum                        1 Adamu Lane, Abuja    140
# 3          Susan Nwaimo       Number 58 Yaba Street, Kaduna State     160
# 4          Ajao Opeyemi             No12 Olubunmi Street, Abeokuta     18
# 5     Banjoko Adebusola             34 Ngige Street, Ugheli, Delta     14
# 6      Muhammed Olabisi                       13, ICAN road, Enugu      -1
# 7   Oluwagbemi Mojisola                         ACCA Lane, Onitsha      -1
# 8          Susan Nwaimo       Number 58 Yaba Street, Kaduna State      16
# 9          Ajao Opeyemi             No12 Olubunmi Street, Abeokuta     18
#
#     Gender
# 0     Male
# 1     Male
# 2     Male
# 3   Female
# 4   Female
# 5   Female
# 6   Female
# 7   Female
# 8   Female
# 9   Female

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     10 non-null     object
#  1   Address  10 non-null     object
#  2   Age      10 non-null     object
#  3   Gender   10 non-null     object
# dtypes: object(4)
# memory usage: 448.0+ bytes

# %%
#converte uma coluna para inteiro
df['Age'] = pd.to_numeric(df.Age, downcast = "integer")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     10 non-null     object
#  1   Address  10 non-null     object
#  2   Age      10 non-null     int16
#  3   Gender   10 non-null     object
# dtypes: int16(1), object(3)
# memory usage: 388.0+ bytes

# %%
#mostra todos os registros com idade > 100
df.loc[df['Age'] > 100]
# Out:
#              Name                                 Address  Age   Gender
# 2    Alex Ezurum                     1 Adamu Lane, Abuja   140     Male
# 3   Susan Nwaimo    Number 58 Yaba Street, Kaduna State    160   Female

# %%
df['Age'].loc[df['Age'] > 100] = df['Age']/10

df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#                     Name                                    Address   Age  \
# 0        Hussein Hakeem    Number 22 Fioye Crescent Surulere Lagos   17.0
# 1        Arojoye Samuel        11 Omolade Close Omole Estate Lagos   16.0
# 2           Alex Ezurum                        1 Adamu Lane, Abuja   14.0
# 3          Susan Nwaimo       Number 58 Yaba Street, Kaduna State    16.0
# 4          Ajao Opeyemi             No12 Olubunmi Street, Abeokuta   18.0
# 5     Banjoko Adebusola             34 Ngige Street, Ugheli, Delta   14.0
# 6      Muhammed Olabisi                       13, ICAN road, Enugu   -1.0
# ...

# %%
import math
#df2 = df.copy()
df['Age'].loc[df['Age'] < 0 ] = math.floor(df['Age'].mean())
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#                     Name                                    Address   Age  \
# 0        Hussein Hakeem    Number 22 Fioye Crescent Surulere Lagos   17.0
# 1        Arojoye Samuel        11 Omolade Close Omole Estate Lagos   16.0
# 2           Alex Ezurum                        1 Adamu Lane, Abuja   14.0
# 3          Susan Nwaimo       Number 58 Yaba Street, Kaduna State    16.0
# 4          Ajao Opeyemi             No12 Olubunmi Street, Abeokuta   18.0
# 5     Banjoko Adebusola             34 Ngige Street, Ugheli, Delta   14.0
# 6      Muhammed Olabisi                       13, ICAN road, Enugu   12.0
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#                     Name                                    Address   Age  \
# 0        Hussein Hakeem    Number 22 Fioye Crescent Surulere Lagos   17.0
# 1        Arojoye Samuel        11 Omolade Close Omole Estate Lagos   16.0
# 2           Alex Ezurum                        1 Adamu Lane, Abuja   14.0
# 3          Susan Nwaimo       Number 58 Yaba Street, Kaduna State    16.0
# 4          Ajao Opeyemi             No12 Olubunmi Street, Abeokuta   18.0
# 5     Banjoko Adebusola             34 Ngige Street, Ugheli, Delta   14.0
# 6      Muhammed Olabisi                       13, ICAN road, Enugu   12.0
# 7   Oluwagbemi Mojisola                         ACCA Lane, Onitsha   12.0
#
#     Gender
# 0     Male
# 1     Male
# 2     Male
# 3   Female
# 4   Female
# 5   Female
# 6   Female
# 7   Female
